# %% [markdown]
# # Inequality in Educational Opportunity - Data Preparation
#
# In this notebook, we will prepare the education dataset for analysis. This includes data cleaning, handling missing values and ensuring the dataset is ready for exploratory data analysis (EDA).
#
# ---

# %% [markdown]
# ## Project Overview
#
# This project addresses inequality of educational opportunity in U.S. high schools. Here we will focus on average student performance on the ACT or SAT exams that students take as part of the college application process.
#
# We expect a range of school performance on these exams, but is school performance associated with socioeconomic factors?
#
# Can school performance be predicted based on socioeconomic factors?

# %% [markdown]
# ## Data Sources
#
# ### School Performance Data
# The primary data source is the [EdGap.org](https://edgap.org/) dataset, which compiles high school performance data on the ACT and SAT exams along with socioeconomic indicators for each school.
#
# ### School Information Data
# The school information data is from the [National Center for Education Statistics](https://nces.ed.gov/ccd/pubschuniv.asp). This data set consists of basic identifying information about schools including location, type of school, and enrollment.
#
# ### School District Financial Data (additional predictor data source)
# The school financial data is from the [National Center for Education Statistics](https://nces.ed.gov/ccd/data_slfs.asp). This dataset includes information on district level funding, expenditures, and financial resources.
#
#
#
# In this notebook, we will prepare a dataset for analysis and visualization. We will combine data from 3 sources, clean the data, and perform imputation where necessary.

# %% [markdown]
# ## Load The Data

# %% [markdown]
# We will import the necessary libraries, and load data gathered from EdGap.org with school performance information and the National Center for Education Statistics (NCES) with school information and financial data into dataframes.

# %% [markdown]
# ### Import libraries

# %% [markdown]
# Import necessary libraries.

# %%
# Import pandas, numpy, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# seaborn is a data visualization library built on matplotlib
import seaborn as sns

# set the plotting style
sns.set_style("whitegrid")
sns.set_palette('deep')

# %% [markdown]
# Load the csv files from EdGap.org with school performance information and the
# National Center for Education Statistics (NCES) with school information and financial data into dataframes.

# %%
edgap = pd.read_excel(
    'https://github.com/JLichwa80/education/raw/refs/heads/master/data/EdGap_data.xlsx'
)
edgap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7986 entries, 0 to 7985
# Data columns (total 7 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   NCESSCH School ID                                7986 non-null   int64
#  1   CT Unemployment Rate                             7972 non-null   float64
#  2   CT Pct Adults with College Degree                7973 non-null   float64
#  3   CT Pct Childre In Married Couple Family          7961 non-null   float64
#  4   CT Median Household Income                       7966 non-null   float64
#  5   School ACT average (or equivalent if SAT score)  7986 non-null   float64
#  6   School Pct Free and Reduced Lunch                7986 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 436.9 KB
# c:\Users\Jack\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:85: UserWarning:
#
# Unknown extension is not supported and will be removed

# %%
school_information = pd.read_csv(
    "../data/ccd_sch_029_1617_w_1a_11212017.csv", encoding="unicode_escape"
)
school_information.info()
# Out:
# C:\Users\Jack\AppData\Local\Temp\ipykernel_19200\2530103164.py:1: DtypeWarning:
#
# Columns (6,9,14,15,18,19,21,22,25,26,29,31,35,39,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102183 entries, 0 to 102182
# Data columns (total 65 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SCHOOL_YEAR          102183 non-null  object
#  1   FIPST                102183 non-null  int64
#  2   STATENAME            102183 non-null  object
#  3   ST                   102183 non-null  object
#  4   SCH_NAME             102183 non-null  object
#  5   LEA_NAME             102183 non-null  object
#  6   STATE_AGENCY_NO      102183 non-null  object
#  7   UNION                2533 non-null    float64
#  8   ST_LEAID             102183 non-null  object
#  9   LEAID                102183 non-null  object
#  10  ST_SCHID             102183 non-null  object
#  11  NCESSCH              102181 non-null  float64
#  12  SCHID                102181 non-null  float64
#  13  MSTREET1             102181 non-null  object
#  14  MSTREET2             1825 non-null    object
#  15  MSTREET3             28 non-null      object
#  16  MCITY                102183 non-null  object
#  17  MSTATE               102183 non-null  object
#  18  MZIP                 102183 non-null  object
#  19  MZIP4                60419 non-null   object
#  20  LSTREET1             102183 non-null  object
#  21  LSTREET2             582 non-null     object
#  22  LSTREET3             13 non-null      object
#  23  LCITY                102183 non-null  object
#  24  LSTATE               102183 non-null  object
#  25  LZIP                 102183 non-null  object
#  26  LZIP4                59145 non-null   object
#  27  PHONE                102183 non-null  object
#  28  WEBSITE              51983 non-null   object
#  29  SY_STATUS            102181 non-null  object
#  30  SY_STATUS_TEXT       102181 non-null  object
#  31  UPDATED_STATUS       102181 non-null  object
#  32  UPDATED_STATUS_TEXT  102181 non-null  object
#  33  EFFECTIVE_DATE       102181 non-null  object
#  34  SCH_TYPE_TEXT        102181 non-null  object
#  35  SCH_TYPE             102181 non-null  object
#  36  RECON_STATUS         102181 non-null  object
#  37  OUT_OF_STATE_FLAG    102179 non-null  object
#  38  CHARTER_TEXT         102179 non-null  object
#  39  CHARTAUTH1           6687 non-null    object
#  40  CHARTAUTHN1          6687 non-null    object
#  41  CHARTAUTH2           116 non-null     object
#  42  CHARTAUTHN2          116 non-null     object
#  43  NOGRADES             102179 non-null  object
#  44  G_PK_OFFERED         102179 non-null  object
#  45  G_KG_OFFERED         102179 non-null  object
#  46  G_1_OFFERED          102179 non-null  object
#  47  G_2_OFFERED          102179 non-null  object
#  48  G_3_OFFERED          102179 non-null  object
#  49  G_4_OFFERED          102179 non-null  object
#  50  G_5_OFFERED          102179 non-null  object
#  51  G_6_OFFERED          102179 non-null  object
#  52  G_7_OFFERED          102179 non-null  object
#  53  G_8_OFFERED          102179 non-null  object
#  54  G_9_OFFERED          102179 non-null  object
#  55  G_10_OFFERED         102179 non-null  object
#  56  G_11_OFFERED         102179 non-null  object
#  57  G_12_OFFERED         102179 non-null  object
#  58  G_13_OFFERED         102179 non-null  object
#  59  G_UG_OFFERED         102179 non-null  object
#  60  G_AE_OFFERED         102179 non-null  object
#  61  GSLO                 102179 non-null  object
#  62  GSHI                 102179 non-null  object
#  63  LEVEL                102179 non-null  object
#  64  IGOFFERED            102179 non-null  object
# dtypes: float64(3), int64(1), object(61)
# memory usage: 50.7+ MB

# %%
school_finance = pd.read_excel(
    'https://github.com/JLichwa80/education/raw/refs/heads/master/data/district_finances.xlsx'
)
### Update 0 and negative values to NaN (based on documentation that negative values indicates missing data)
school_finance.loc[school_finance['TOTALEXP'] <= 0, 'TOTALEXP'] = np.nan
school_finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18680 entries, 0 to 18679
# Data columns (total 260 columns):
#  #    Column        Non-Null Count  Dtype
# ---   ------        --------------  -----
#  0    LEAID         18680 non-null  object
#  1    CENSUSID      18680 non-null  object
#  2    FIPST         18680 non-null  int64
#  3    CONUM         18680 non-null  object
#  4    CSA           18680 non-null  object
#  5    CBSA          18680 non-null  object
#  6    NAME          18680 non-null  object
#  7    STNAME        18680 non-null  object
#  8    STABBR        18680 non-null  object
#  9    SCHLEV        18680 non-null  object
#  10   AGCHRT        18680 non-null  object
#  11   YEAR          18680 non-null  int64
#  12   CCDNF         18680 non-null  int64
#  13   CENFILE       18680 non-null  int64
#  14   GSLO          18680 non-null  object
#  15   GSHI          18680 non-null  object
#  16   V33           18680 non-null  int64
#  17   MEMBERSCH     18680 non-null  int64
#  18   TOTALREV      18680 non-null  int64
#  19   TFEDREV       18680 non-null  int64
#  20   C14           18680 non-null  int64
#  21   C15           18680 non-null  int64
#  22   C16           18680 non-null  int64
#  23   C17           18680 non-null  int64
#  24   C19           18680 non-null  int64
#  25   B11           18680 non-null  int64
#  26   C20           18680 non-null  int64
#  27   C25           18680 non-null  int64
#  28   C36           18680 non-null  int64
#  29   B10           18680 non-null  int64
#  30   B12           18680 non-null  int64
#  31   B13           18680 non-null  int64
#  32   TSTREV        18680 non-null  int64
#  33   C01           18680 non-null  int64
#  34   C04           18680 non-null  int64
#  35   C05           18680 non-null  int64
#  36   C06           18680 non-null  int64
#  37   C07           18680 non-null  int64
#  38   C08           18680 non-null  int64
#  39   C09           18680 non-null  int64
#  40   C10           18680 non-null  int64
#  41   C11           18680 non-null  int64
#  42   C12           18680 non-null  int64
#  43   C13           18680 non-null  int64
#  44   C35           18680 non-null  int64
#  45   C38           18680 non-null  int64
#  46   C39           18680 non-null  int64
#  47   TLOCREV       18680 non-null  int64
#  48   T02           18680 non-null  int64
#  49   T06           18680 non-null  int64
#  50   T09           18680 non-null  int64
#  51   T15           18680 non-null  int64
#  52   T40           18680 non-null  int64
#  53   T99           18680 non-null  int64
#  54   D11           18680 non-null  int64
#  55   D23           18680 non-null  int64
#  56   A07           18680 non-null  int64
#  57   A08           18680 non-null  int64
#  58   A09           18680 non-null  int64
#  59   A11           18680 non-null  int64
#  60   A13           18680 non-null  int64
#  61   A15           18680 non-null  int64
#  62   A20           18680 non-null  int64
#  63   A40           18680 non-null  int64
#  64   U11           18680 non-null  int64
#  65   U22           18680 non-null  int64
#  66   U30           18680 non-null  int64
#  67   U50           18680 non-null  int64
#  68   U97           18680 non-null  int64
#  69   C24           18680 non-null  int64
#  70   TOTALEXP      17010 non-null  float64
#  71   TCURELSC      18680 non-null  int64
#  72   TCURINST      18680 non-null  int64
#  73   E13           18680 non-null  int64
#  74   V91           18680 non-null  int64
#  75   V92           18680 non-null  int64
#  76   TCURSSVC      18680 non-null  int64
#  77   E17           18680 non-null  int64
#  78   E07           18680 non-null  int64
#  79   E08           18680 non-null  int64
#  80   E09           18680 non-null  int64
#  81   V40           18680 non-null  int64
#  82   V45           18680 non-null  int64
#  83   V90           18680 non-null  int64
#  84   V85           18680 non-null  int64
#  85   TCUROTH       18680 non-null  int64
#  86   E11           18680 non-null  int64
#  87   V60           18680 non-null  int64
#  88   V65           18680 non-null  int64
#  89   TNONELSE      18680 non-null  int64
#  90   V70           18680 non-null  int64
#  91   V75           18680 non-null  int64
#  92   V80           18680 non-null  int64
#  93   TCAPOUT       18680 non-null  int64
#  94   F12           18680 non-null  int64
#  95   G15           18680 non-null  int64
#  96   K09           18680 non-null  int64
#  97   K10           18680 non-null  int64
#  98   K11           18680 non-null  int64
#  99   L12           18680 non-null  int64
#  100  M12           18680 non-null  int64
#  101  Q11           18680 non-null  int64
#  102  I86           18680 non-null  int64
#  103  Z32           18680 non-null  int64
#  104  Z33           18680 non-null  int64
#  105  Z35           18680 non-null  int64
#  106  Z36           18680 non-null  int64
#  107  Z37           18680 non-null  int64
#  108  Z38           18680 non-null  int64
#  109  V11           18680 non-null  int64
#  110  V13           18680 non-null  int64
#  111  V15           18680 non-null  int64
#  112  V17           18680 non-null  int64
#  113  V21           18680 non-null  int64
#  114  V23           18680 non-null  int64
#  115  V37           18680 non-null  int64
#  116  V29           18680 non-null  int64
#  117  Z34           18680 non-null  int64
#  118  V10           18680 non-null  int64
#  119  V12           18680 non-null  int64
#  120  V14           18680 non-null  int64
#  121  V16           18680 non-null  int64
#  122  V18           18680 non-null  int64
#  123  V22           18680 non-null  int64
#  124  V24           18680 non-null  int64
#  125  V38           18680 non-null  int64
#  126  V30           18680 non-null  int64
#  127  V32           18680 non-null  int64
#  128  V93           18680 non-null  int64
#  129  _19H          18680 non-null  int64
#  130  _21F          18680 non-null  int64
#  131  _31F          18680 non-null  int64
#  132  _41F          18680 non-null  int64
#  133  _61V          18680 non-null  int64
#  134  _66V          18680 non-null  int64
#  135  W01           18680 non-null  int64
#  136  W31           18680 non-null  int64
#  137  W61           18680 non-null  int64
#  138  V95           18680 non-null  int64
#  139  V02           18680 non-null  int64
#  140  K14           18680 non-null  int64
#  141  CE1           18680 non-null  int64
#  142  CE2           18680 non-null  int64
#  143  WEIGHT        18680 non-null  int64
#  144  FL_V33        18680 non-null  object
#  145  FL_MEMBERSCH  18680 non-null  object
#  146  FL_C14        18680 non-null  object
#  147  FL_C15        18680 non-null  object
#  148  FL_C16        18680 non-null  object
#  149  FL_C17        18680 non-null  object
#  150  FL_C19        18680 non-null  object
#  151  FL_B11        18680 non-null  object
#  152  FL_C20        18680 non-null  object
#  153  FL_C25        18680 non-null  object
#  154  FL_C36        18680 non-null  object
#  155  FL_B10        18680 non-null  object
#  156  FL_B12        18680 non-null  object
#  157  FL_B13        18680 non-null  object
#  158  FL_C01        18680 non-null  object
#  159  FL_C04        18680 non-null  object
#  160  FL_C05        18680 non-null  object
#  161  FL_C06        18680 non-null  object
#  162  FL_C07        18680 non-null  object
#  163  FL_C08        18680 non-null  object
#  164  FL_C09        18680 non-null  object
#  165  FL_C10        18680 non-null  object
#  166  FL_C11        18680 non-null  object
#  167  FL_C12        18680 non-null  object
#  168  FL_C13        18680 non-null  object
#  169  FL_C35        18680 non-null  object
#  170  FL_C38        18680 non-null  object
#  171  FL_C39        18680 non-null  object
#  172  FL_T02        18680 non-null  object
#  173  FL_T06        18680 non-null  object
#  174  FL_T09        18680 non-null  object
#  175  FL_T15        18680 non-null  object
#  176  FL_T40        18680 non-null  object
#  177  FL_T99        18680 non-null  object
#  178  FL_D11        18680 non-null  object
#  179  FL_D23        18680 non-null  object
#  180  FL_A07        18680 non-null  object
#  181  FL_A08        18680 non-null  object
#  182  FL_A09        18680 non-null  object
#  183  FL_A11        18680 non-null  object
#  184  FL_A13        18680 non-null  object
#  185  FL_A15        18680 non-null  object
#  186  FL_A20        18680 non-null  object
#  187  FL_A40        18680 non-null  object
#  188  FL_U11        18680 non-null  object
#  189  FL_U22        18680 non-null  object
#  190  FL_U30        18680 non-null  object
#  191  FL_U50        18680 non-null  object
#  192  FL_U97        18680 non-null  object
#  193  FL_C24        18680 non-null  object
#  194  FL_E13        18680 non-null  object
#  195  FL_V91        18680 non-null  object
#  196  FL_V92        18680 non-null  object
#  197  FL_E17        18680 non-null  object
#  198  FL_E07        18680 non-null  object
#  199  FL_E08        18680 non-null  object
#  200  FL_E09        18680 non-null  object
#  201  FL_V40        18680 non-null  object
#  202  FL_V45        18680 non-null  object
#  203  FL_V90        18680 non-null  object
#  204  FL_V85        18680 non-null  object
#  205  FL_E11        18680 non-null  object
#  206  FL_V60        18680 non-null  object
#  207  FL_V65        18680 non-null  object
#  208  FL_V70        18680 non-null  object
#  209  FL_V75        18680 non-null  object
#  210  FL_V80        18680 non-null  object
#  211  FL_F12        18680 non-null  object
#  212  FL_G15        18680 non-null  object
#  213  FL_K09        18680 non-null  object
#  214  FL_K10        18680 non-null  object
#  215  FL_K11        18680 non-null  object
#  216  FL_L12        18680 non-null  object
#  217  FL_M12        18680 non-null  object
#  218  FL_Q11        18680 non-null  object
#  219  FL_I86        18680 non-null  object
#  220  FL_Z32        18680 non-null  object
#  221  FL_Z33        18680 non-null  object
#  222  FL_Z35        18680 non-null  object
#  223  FL_Z36        18680 non-null  object
#  224  FL_Z37        18680 non-null  object
#  225  FL_Z38        18680 non-null  object
#  226  FL_V11        18680 non-null  object
#  227  FL_V13        18680 non-null  object
#  228  FL_V15        18680 non-null  object
#  229  FL_V17        18680 non-null  object
#  230  FL_V21        18680 non-null  object
#  231  FL_V23        18680 non-null  object
#  232  FL_V37        18680 non-null  object
#  233  FL_V29        18680 non-null  object
#  234  FL_Z34        18680 non-null  object
#  235  FL_V10        18680 non-null  object
#  236  FL_V12        18680 non-null  object
#  237  FL_V14        18680 non-null  object
#  238  FL_V16        18680 non-null  object
#  239  FL_V18        18680 non-null  object
#  240  FL_V22        18680 non-null  object
#  241  FL_V24        18680 non-null  object
#  242  FL_V38        18680 non-null  object
#  243  FL_V30        18680 non-null  object
#  244  FL_V32        18680 non-null  object
#  245  FL_V93        18680 non-null  object
#  246  FL_19H        18680 non-null  object
#  247  FL_21F        18680 non-null  object
#  248  FL_31F        18680 non-null  object
#  249  FL_41F        18680 non-null  object
#  250  FL_61V        18680 non-null  object
#  251  FL_66V        18680 non-null  object
#  252  FL_W01        18680 non-null  object
#  253  FL_W31        18680 non-null  object
#  254  FL_W61        18680 non-null  object
#  255  FL_V95        18680 non-null  object
#  256  FL_V02        18680 non-null  object
#  257  FL_K14        18680 non-null  object
#  258  FL_CE1        18680 non-null  object
#  259  FL_CE2        18680 non-null  object
# dtypes: float64(1), int64(131), object(128)
# memory usage: 37.1+ MB

# %% [markdown]
# ## Explore the Data

# %% [markdown]
# Perform initial exploration of the data to understand its structure and content.
#
# ##### Examine the datasets
# Let's examine the structure and content of our loaded datasets.

# %%
pd.set_option('display.max_columns', None)  # Show all columns
school_information.head()
# Out:
#   SCHOOL_YEAR  FIPST STATENAME  ST                          SCH_NAME  \
# 0   2016-2017      1   ALABAMA  AL  Sequoyah Sch - Chalkville Campus
# 1   2016-2017      1   ALABAMA  AL                             Camps
# 2   2016-2017      1   ALABAMA  AL                           Det Ctr
# 3   2016-2017      1   ALABAMA  AL     Wallace Sch - Mt Meigs Campus
# 4   2016-2017      1   ALABAMA  AL         McNeel Sch - Vacca Campus
#
#                  LEA_NAME STATE_AGENCY_NO  UNION ST_LEAID   LEAID  \
# 0  Alabama Youth Services               1    NaN   AL-210  100002
# 1  Alabama Youth Services               1    NaN   AL-210  100002
# 2  Alabama Youth Services               1    NaN   AL-210  100002
# 3  Alabama Youth Services               1    NaN   AL-210  100002
# 4  Alabama Youth Services               1    NaN   AL-210  100002
#
#       ST_SCHID       NCESSCH     SCHID           MSTREET1 MSTREET2 MSTREET3  \
# 0  AL-210-0020  1.000020e+10  100277.0       P O Box 9486      NaN      NaN
# 1  AL-210-0050  1.000020e+10  101667.0         P O Box 66      NaN      NaN
# 2  AL-210-0060  1.000020e+10  101670.0         P O Box 66      NaN      NaN
# 3  AL-210-0030  1.000020e+10  101705.0         P O Box 66      NaN      NaN
# 4  AL-210-0040  1.000020e+10  101706.0  8950 Roebuck Blvd      NaN      NaN
#
#          MCITY MSTATE   MZIP MZIP4                     LSTREET1 LSTREET2  \
# 0   Birmingham     AL  35220   NaN  1000 Industrial School Road      NaN
# 1     Mt Meigs     AL  36057   NaN           1601 County Rd. 57      NaN
# 2     Mt Meigs     AL  36057   NaN       2109 Bashi Rd Bldg 509      NaN
# 3  Mount Meigs     AL  36057   NaN  1000 Industrial School Road      NaN
# 4   Birmingham     AL  35206   NaN            8950 Roebuck Blvd      NaN
#
#   LSTREET3        LCITY LSTATE   LZIP LZIP4          PHONE  \
# 0      NaN   Birmingham     AL  35220   NaN  (205)680-8574
# 1      NaN   Prattville     AL  36067   NaN  (334)215-3850
# 2      NaN  Thomasville     AL  36784   NaN  (334)215-3850
# 3      NaN  Mount Meigs     AL  36057   NaN  (334)215-6039
# 4      NaN   Birmingham     AL  35206   NaN  (205)838-4981
#
#                       WEBSITE SY_STATUS SY_STATUS_TEXT UPDATED_STATUS  \
# 0  http://www.dys.alabama.gov         1           Open              1
# 1  http://www.dys.alabama.gov         1           Open              1
# 2  http://www.dys.alabama.gov         1           Open              1
# 3  http://www.dys.alabama.gov         1           Open              1
# 4  http://www.dys.alabama.gov         1           Open              1
#
#   UPDATED_STATUS_TEXT EFFECTIVE_DATE       SCH_TYPE_TEXT SCH_TYPE  \
# 0                Open     03/03/2010  Alternative School        4
# 1                Open     03/03/2010  Alternative School        4
# 2                Open     03/03/2010  Alternative School        4
# 3                Open     03/03/2010  Alternative School        4
# 4                Open     03/03/2010  Alternative School        4
#
#   RECON_STATUS OUT_OF_STATE_FLAG CHARTER_TEXT CHARTAUTH1 CHARTAUTHN1  \
# 0           No                No           No        NaN         NaN
# 1           No                No           No        NaN         NaN
# 2           No                No           No        NaN         NaN
# 3           No                No           No        NaN         NaN
# 4           No                No           No        NaN         NaN
#
#   CHARTAUTH2 CHARTAUTHN2 NOGRADES G_PK_OFFERED G_KG_OFFERED G_1_OFFERED  \
# 0        NaN         NaN       No           No           No          No
# 1        NaN         NaN       No           No           No          No
# 2        NaN         NaN       No           No           No          No
# 3        NaN         NaN       No           No           No          No
# 4        NaN         NaN       No           No           No          No
#
#   G_2_OFFERED G_3_OFFERED G_4_OFFERED G_5_OFFERED G_6_OFFERED G_7_OFFERED  \
# 0          No          No          No          No          No         Yes
# 1          No          No          No          No          No         Yes
# 2          No          No          No          No          No         Yes
# 3          No          No          No          No          No         Yes
# 4          No          No          No          No          No         Yes
#
#   G_8_OFFERED G_9_OFFERED G_10_OFFERED G_11_OFFERED G_12_OFFERED G_13_OFFERED  \
# 0         Yes         Yes          Yes          Yes          Yes           No
# 1         Yes         Yes          Yes          Yes          Yes           No
# 2         Yes         Yes          Yes          Yes          Yes           No
# 3         Yes         Yes          Yes          Yes          Yes           No
# 4         Yes         Yes          Yes          Yes          Yes           No
#
#   G_UG_OFFERED G_AE_OFFERED GSLO GSHI LEVEL    IGOFFERED
# 0           No           No   07   12  High  As reported
# 1           No           No   07   12  High  As reported
# 2           No           No   07   12  High  As reported
# 3           No           No   07   12  High  As reported
# 4           No           No   07   12  High  As reported

# %%
school_information.shape
# Out:
# (102183, 65)

# %% [markdown]
# We can see information about schools like location, school type, public or private which will help us in the analysis later on.

# %%
edgap.head()
# Out:
#    NCESSCH School ID  CT Unemployment Rate  CT Pct Adults with College Degree  \
# 0       100001600143              0.117962                           0.445283
# 1       100008000024              0.063984                           0.662765
# 2       100008000225              0.056460                           0.701864
# 3       100017000029              0.044739                           0.692062
# 4       100018000040              0.077014                           0.640060
#
#    CT Pct Childre In Married Couple Family  CT Median Household Income  \
# 0                                 0.346495                     42820.0
# 1                                 0.767619                     89320.0
# 2                                 0.713090                     84140.0
# 3                                 0.641283                     56500.0
# 4                                 0.834402                     54015.0
#
#    School ACT average (or equivalent if SAT score)  \
# 0                                        20.433455
# 1                                        19.498168
# 2                                        19.554335
# 3                                        17.737485
# 4                                        18.245421
#
#    School Pct Free and Reduced Lunch
# 0                           0.066901
# 1                           0.112412
# 2                           0.096816
# 3                           0.296960
# 4                           0.262641

# %%
edgap.shape
# Out:
# (7986, 7)

# %% [markdown]
# From this dataset we can gather information about school performance, rates of free/reduced lunch eligibility, and other socioeconomic indicators.

# %%
school_finance.head()
# Out:
#      LEAID CENSUSID  FIPST  CONUM  CSA   CBSA  \
# 0  1000021        N     10  10001  428  20100
# 1  1000022        N     10  10003  428  37980
# 2  1000060        N     10  10001  428  20100
# 3  1100060        N     11  11001  548  47900
# 4  1100078        N     11  11001  548  47900
#
#                                                 NAME                STNAME  \
# 0                                  Corrections - DOE              Delaware
# 1  Dept. of Svs. for Children Youth & Their Families              Delaware
# 2               Mapleton Charter School at Whitehall              Delaware
# 3                            Potomac Preparatory PCS  District of Columbia
# 4                             State Operative Agency  District of Columbia
#
#   STABBR SCHLEV AGCHRT  YEAR  CCDNF  CENFILE GSLO GSHI  V33  MEMBERSCH  \
# 0     DE      N      N    17      1        0    N    N   -2         -2
# 1     DE      N      N    17      1        0    N    N   -2         -2
# 2     DE      N      N    17      1        0    M    M   -2         -2
# 3     DC      N      N    17      1        0    M    M   -2         -2
# 4     DC      N      N    17      1        0    M    M   -2         -2
#
#    TOTALREV  TFEDREV  C14  C15  C16  C17  C19  B11  C20  C25  C36  B10  B12  \
# 0        -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 1        -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 2        -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 3        -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 4        -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
#
#    B13  TSTREV  C01  C04  C05  C06  C07  C08  C09  C10  C11  C12  C13  C35  \
# 0   -2      -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 1   -2      -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 2   -2      -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 3   -2      -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 4   -2      -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
#
#    C38  C39  TLOCREV  T02  T06  T09  T15  T40  T99  D11  D23  A07  A08  A09  \
# 0   -2   -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 1   -2   -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 2   -2   -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 3   -2   -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 4   -2   -2       -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
#
#    A11  A13  A15  A20  A40  U11  U22  U30  U50  U97  C24  TOTALEXP  TCURELSC  \
# 0   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2       NaN        -2
# 1   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2       NaN        -2
# 2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2       NaN        -2
# 3   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2       NaN        -2
# 4   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2       NaN        -2
#
#    TCURINST  E13  V91  V92  TCURSSVC  E17  E07  E08  E09  V40  V45  V90  V85  \
# 0        -2   -2   -2   -2        -2   -2   -2   -2   -2   -2   -2   -2   -2
# 1        -2   -2   -2   -2        -2   -2   -2   -2   -2   -2   -2   -2   -2
# 2        -2   -2   -2   -2        -2   -2   -2   -2   -2   -2   -2   -2   -2
# 3        -2   -2   -2   -2        -2   -2   -2   -2   -2   -2   -2   -2   -2
# 4        -2   -2   -2   -2        -2   -2   -2   -2   -2   -2   -2   -2   -2
#
#    TCUROTH  E11  V60  V65  TNONELSE  V70  V75  V80  TCAPOUT  F12  G15  K09  \
# 0       -2   -2   -2   -2        -2   -2   -2   -2       -2   -2   -2   -2
# 1       -2   -2   -2   -2        -2   -2   -2   -2       -2   -2   -2   -2
# 2       -2   -2   -2   -2        -2   -2   -2   -2       -2   -2   -2   -2
# 3       -2   -2   -2   -2        -2   -2   -2   -2       -2   -2   -2   -2
# 4       -2   -2   -2   -2        -2   -2   -2   -2       -2   -2   -2   -2
#
#    K10  K11  L12  M12  Q11  I86  Z32  Z33  Z35  Z36  Z37  Z38  V11  V13  V15  \
# 0   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 1   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 3   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 4   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
#
#    V17  V21  V23  V37  V29  Z34  V10  V12  V14  V16  V18  V22  V24  V38  V30  \
# 0   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 1   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 3   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
# 4   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2   -2
#
#    V32  V93  _19H  _21F  _31F  _41F  _61V  _66V  W01  W31  W61  V95  V02  K14  \
# 0   -2   -2    -2    -2    -2    -2    -2    -2   -2   -2   -2   -2   -2   -2
# 1   -2   -2    -2    -2    -2    -2    -2    -2   -2   -2   -2   -2   -2   -2
# 2   -2   -2    -2    -2    -2    -2    -2    -2   -2   -2   -2   -2   -2   -2
# 3   -2   -2    -2    -2    -2    -2    -2    -2   -2   -2   -2   -2   -2   -2
# 4   -2   -2    -2    -2    -2    -2    -2    -2   -2   -2   -2   -2   -2   -2
#
#    CE1  CE2  WEIGHT FL_V33 FL_MEMBERSCH FL_C14 FL_C15 FL_C16 FL_C17 FL_C19  \
# 0   -2   -2       1      N            N      N      N      N      N      N
# 1   -2   -2       1      N            N      N      N      N      N      N
# 2   -2   -2       1      N            N      N      N      N      N      N
# 3   -2   -2       1      N            N      N      N      N      N      N
# 4   -2   -2       1      N            N      N      N      N      N      N
#
#   FL_B11 FL_C20 FL_C25 FL_C36 FL_B10 FL_B12 FL_B13 FL_C01 FL_C04 FL_C05  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_C06 FL_C07 FL_C08 FL_C09 FL_C10 FL_C11 FL_C12 FL_C13 FL_C35 FL_C38  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_C39 FL_T02 FL_T06 FL_T09 FL_T15 FL_T40 FL_T99 FL_D11 FL_D23 FL_A07  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_A08 FL_A09 FL_A11 FL_A13 FL_A15 FL_A20 FL_A40 FL_U11 FL_U22 FL_U30  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_U50 FL_U97 FL_C24 FL_E13 FL_V91 FL_V92 FL_E17 FL_E07 FL_E08 FL_E09  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_V40 FL_V45 FL_V90 FL_V85 FL_E11 FL_V60 FL_V65 FL_V70 FL_V75 FL_V80  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_F12 FL_G15 FL_K09 FL_K10 FL_K11 FL_L12 FL_M12 FL_Q11 FL_I86 FL_Z32  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_Z33 FL_Z35 FL_Z36 FL_Z37 FL_Z38 FL_V11 FL_V13 FL_V15 FL_V17 FL_V21  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_V23 FL_V37 FL_V29 FL_Z34 FL_V10 FL_V12 FL_V14 FL_V16 FL_V18 FL_V22  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_V24 FL_V38 FL_V30 FL_V32 FL_V93 FL_19H FL_21F FL_31F FL_41F FL_61V  \
# 0      N      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N      N
#
#   FL_66V FL_W01 FL_W31 FL_W61 FL_V95 FL_V02 FL_K14 FL_CE1 FL_CE2
# 0      N      N      N      N      N      N      N      N      N
# 1      N      N      N      N      N      N      N      N      N
# 2      N      N      N      N      N      N      N      N      N
# 3      N      N      N      N      N      N      N      N      N
# 4      N      N      N      N      N      N      N      N      N

# %%
school_finance.shape
# Out:
# (18680, 260)

# %% [markdown]
# From above dataset we can gather information about school district funding, expenditures, and financial resources. We can see that many financial columns have no data which we will need to address in the data cleaning process.

# %% [markdown]
# Initial data exploration findings:
# - Limited data in Edgap :Edgap with ACT/SAT scores has 7986 schools vs school information dataset provides school characteristics for 102183 schools
# - School Id formats differ: Edgap is Integer, School Information is float, and Financial Data is object (string)

# %% [markdown]
# #### Analyze Edgap relationships between ACT/SAT scores and socioeconomic indicators

# %% [markdown]
# Analyze relationships between ACT/SAT scores and socioeconomic indicators such as free/reduced lunch eligibility, school funding, and expenditures.

# %%
sns.pairplot(
    edgap.drop(columns="NCESSCH School ID")
)
plt.show()

# %% [markdown]
# From the initial exploration of the data we can see that there are several variables that may be related to educational opportunity. For example, Schools Free Lunch Percentage appears to have a negative correlation with Average ACT/SAT Score and Median Household Income appears to have a positive correlation with Average ACT/SAT Score.

# %% [markdown]
# ##### Include regression analysis
# Include regression analysis to better understand the relationships between these variables and educational opportunity.

# %%
fig = sns.pairplot(
    edgap.drop(columns="NCESSCH School ID"),
    kind="reg",
    plot_kws={
        "line_kws": {"color": "blue"},
        "scatter_kws": {"alpha": 0.5, "color": "k", "s": 7},
    },
)

for ax in fig.axes.flat:
    if ax.get_xlabel() == 'CT Median Household Income':
        ax.ticklabel_format(style='sci', axis='x', scilimits=(0,0))  # Apply scientific notation
    ax.set_xlabel(ax.get_xlabel(), fontsize=8, rotation=30, ha='right')  # X-axis label size and rotation
    ax.set_ylabel(ax.get_ylabel(), fontsize=8)  # Y-axis label size

    # Rotate x-axis tick labels
    plt.setp(ax.get_xticklabels(), rotation=30, ha='right')


plt.show()

# %% [markdown]
# In above graphs, we can better identify the type of correlation between variables thanks to regression lines. We can also better see the strength of the correlation by looking at how closely the data points cluster around the regression line. All variables show some degree of correlation with Average ACT/SAT Score with unemployment rate and free lunch percentage showing negative correlation and median household income, percentage of adults with a college degree, percentage of children in married couple families showing positive correlation.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Here we will select relevant variables, rename columns, handle missing values, and merge datasets to create a final dataset for analysis.

# %% [markdown]
# #### Select relevant columns from school information dataset

# %% [markdown]
# The school information data set contains many columns. We only need the year, school identity (NCESSCH), district identity (LEAID), location, and school type information.
#
# Keep the columns `SCHOOL_YEAR`, `NCESSCH`,`LEAID` `LSTATE`, `LZIP`, `SCH_TYPE_TEXT`, `LEVEL`, `CHARTER_TEXT`

# %%
school_information = school_information[
    ['SCHOOL_YEAR', 'NCESSCH', 'LEAID', 'LSTATE', 'LZIP', 'SCH_TYPE_TEXT', 'LEVEL', 'CHARTER_TEXT']
]

# %%
school_information.head()
# Out:
#   SCHOOL_YEAR       NCESSCH   LEAID LSTATE   LZIP       SCH_TYPE_TEXT LEVEL  \
# 0   2016-2017  1.000020e+10  100002     AL  35220  Alternative School  High
# 1   2016-2017  1.000020e+10  100002     AL  36067  Alternative School  High
# 2   2016-2017  1.000020e+10  100002     AL  36784  Alternative School  High
# 3   2016-2017  1.000020e+10  100002     AL  36057  Alternative School  High
# 4   2016-2017  1.000020e+10  100002     AL  35206  Alternative School  High
#
#   CHARTER_TEXT
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No

# %% [markdown]
# The school finances data set contains many detailed columns about school expenditures. We will use that dataset to get total expenditures for school districts (`LEAID`).

# %%
# Financial expenditures by district
school_finance = school_finance[['LEAID', 'TOTALEXP']]
school_finance.head()
# Out:
#      LEAID  TOTALEXP
# 0  1000021       NaN
# 1  1000022       NaN
# 2  1000060       NaN
# 3  1100060       NaN
# 4  1100078       NaN

# %%
school_finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18680 entries, 0 to 18679
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LEAID     18680 non-null  object
#  1   TOTALEXP  17010 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 292.0+ KB

# %% [markdown]
# We can notice that there are some missing values in the expenditures column. Later we will need to decide how to handle missing total expenditures values.
#
# Before that we will work on data structure, filter relevant columns, and merge datasets.

# %% [markdown]
# ### Rename columns for clarity

# %% [markdown]
# We will rename the columns to follow best practices of style and being informative. We can do this before or after joining the data sets. We will do it before joining the data sets to make it obvious that the key has the same name in each data set

# %%
edgap = edgap.rename(
    columns={
        "NCESSCH School ID": "id",
        "CT Pct Adults with College Degree": "percent_college",
        "CT Unemployment Rate": "rate_unemployment",
        "CT Pct Childre In Married Couple Family": "percent_married",
        "CT Median Household Income": "median_income",
        "School ACT average (or equivalent if SAT score)": "average_act",
        "School Pct Free and Reduced Lunch": "percent_lunch",
    }
)
edgap.head()
# Out:
#              id  rate_unemployment  percent_college  percent_married  \
# 0  100001600143           0.117962         0.445283         0.346495
# 1  100008000024           0.063984         0.662765         0.767619
# 2  100008000225           0.056460         0.701864         0.713090
# 3  100017000029           0.044739         0.692062         0.641283
# 4  100018000040           0.077014         0.640060         0.834402
#
#    median_income  average_act  percent_lunch
# 0        42820.0    20.433455       0.066901
# 1        89320.0    19.498168       0.112412
# 2        84140.0    19.554335       0.096816
# 3        56500.0    17.737485       0.296960
# 4        54015.0    18.245421       0.262641

# %%
school_information = school_information.rename(
    columns={
        "SCHOOL_YEAR": "year",
        "NCESSCH": "id",
        "LSTATE": "state",
        "LZIP": "zip_code",
        "SCH_TYPE_TEXT": "school_type",
        "LEVEL": "school_level",
        "CHARTER_TEXT": "charter"
    }
)
school_information.head()
# Out:
#         year            id   LEAID state zip_code         school_type  \
# 0  2016-2017  1.000020e+10  100002    AL    35220  Alternative School
# 1  2016-2017  1.000020e+10  100002    AL    36067  Alternative School
# 2  2016-2017  1.000020e+10  100002    AL    36784  Alternative School
# 3  2016-2017  1.000020e+10  100002    AL    36057  Alternative School
# 4  2016-2017  1.000020e+10  100002    AL    35206  Alternative School
#
#   school_level charter
# 0         High      No
# 1         High      No
# 2         High      No
# 3         High      No
# 4         High      No

# %% [markdown]
# We have successfully reduced the school information data.

# %%
school_finance = school_finance.rename(
    columns={
        'TOTALEXP': 'total_expenditures'
    }
)
school_finance.head()
# Out:
#      LEAID  total_expenditures
# 0  1000021                 NaN
# 1  1000022                 NaN
# 2  1000060                 NaN
# 3  1100060                 NaN
# 4  1100078                 NaN

# %% [markdown]
# We have isolated the district identifier and total expenditures, reducing the
# financial dataset from 260 columns to 2 columns.

# %% [markdown]
# ### Merge Data

# %% [markdown]
# We will clean and convert 'id' column to integer. Then we merge school district finances with school information data frames based on district id (`LEAID`) and them merge edgap with combined school information. Left join allows us to prioritize on ACT/SAT scores data.

# %%
# Clean and pad LEAIDs 
school_finance['LEAID'] = school_finance['LEAID'].astype(str).str.strip().str.zfill(7)
school_information['LEAID'] = school_information['LEAID'].astype(str).str.strip().str.zfill(7)

# Merge school information and school finance data frames on LEAID
df_school_info_combined = school_information.merge(
    school_finance,
    how='left',
    on='LEAID')

# Drop LeadID column as it's no longer needed
df_school_info_combined = df_school_info_combined.drop(columns=['LEAID'])

# Drop School ID NAN and convert it from float to int type
df_school_info_combined = df_school_info_combined.dropna(subset=['id'])
df_school_info_combined['id'] = df_school_info_combined['id'].dropna().round().astype(int)

df = edgap.merge(
    df_school_info_combined,
    how='left',
    on='id')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7986 entries, 0 to 7985
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  7986 non-null   int64
#  1   rate_unemployment   7972 non-null   float64
#  2   percent_college     7973 non-null   float64
#  3   percent_married     7961 non-null   float64
#  4   median_income       7966 non-null   float64
#  5   average_act         7986 non-null   float64
#  6   percent_lunch       7986 non-null   float64
#  7   year                7898 non-null   object
#  8   state               7898 non-null   object
#  9   zip_code            7898 non-null   object
#  10  school_type         7898 non-null   object
#  11  school_level        7898 non-null   object
#  12  charter             7898 non-null   object
#  13  total_expenditures  7498 non-null   float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 873.6+ KB

# %%
df.head()
# Out:
#              id  rate_unemployment  percent_college  percent_married  \
# 0  100001600143           0.117962         0.445283         0.346495
# 1  100008000024           0.063984         0.662765         0.767619
# 2  100008000225           0.056460         0.701864         0.713090
# 3  100017000029           0.044739         0.692062         0.641283
# 4  100018000040           0.077014         0.640060         0.834402
#
#    median_income  average_act  percent_lunch       year state zip_code  \
# 0        42820.0    20.433455       0.066901  2016-2017    DE    19804
# 1        89320.0    19.498168       0.112412  2016-2017    DE    19709
# 2        84140.0    19.554335       0.096816  2016-2017    DE    19709
# 3        56500.0    17.737485       0.296960  2016-2017    DE    19958
# 4        54015.0    18.245421       0.262641  2016-2017    DE    19934
#
#       school_type school_level charter  total_expenditures
# 0  Regular School         High     Yes           6469000.0
# 1  Regular School         High      No         139321000.0
# 2  Regular School         High      No         139321000.0
# 3  Regular School         High      No         143465000.0
# 4  Regular School         High      No         123260000.0

# %% [markdown]
# The high match rate indicates good data quality and compatible school identifiers across datasets. The missing financial records will be addressed through imputationin later steps.

# %% [markdown]
# ### Improve data quality

# %% [markdown]
# Here we will remove invalid data, handle misssing values, and reduce data set to high school level only.

# %% [markdown]
# #### Dataset statistics

# %%
df.describe()
# Out:
#                  id  rate_unemployment  percent_college  percent_married  \
# count  7.986000e+03        7972.000000      7973.000000      7961.000000
# mean   3.321869e+11           0.098730         0.568930         0.633440
# std    1.323638e+11           0.058959         0.165704         0.196764
# min    1.000016e+11           0.000000         0.091493         0.000000
# 25%    2.105340e+11           0.058655         0.450828         0.523810
# 50%    3.600085e+11           0.085649         0.554979         0.667594
# 75%    4.226678e+11           0.123376         0.676571         0.777135
# max    5.605830e+11           0.590278         1.000000         1.000000
#
#        median_income  average_act  percent_lunch  total_expenditures
# count    7966.000000  7986.000000    7986.000000        7.498000e+03
# mean    52026.905222    20.181532       0.420651        3.637461e+08
# std     24228.057079     2.595201       0.239754        8.928322e+08
# min      3589.000000    -3.070818      -0.054545        1.201000e+06
# 25%     36597.250000    18.600000       0.238501        1.851900e+07
# 50%     46833.500000    20.400000       0.381570        5.327650e+07
# 75%     61369.250000    21.910867       0.575447        2.476370e+08
# max    226181.000000    32.362637       0.998729        5.827667e+09

# %%
df.select_dtypes(include=['number']).agg(['min','max']).round(2)
# Out:
#                id  rate_unemployment  percent_college  percent_married  \
# min  100001600143               0.00             0.09              0.0
# max  560583000335               0.59             1.00              1.0
#
#      median_income  average_act  percent_lunch  total_expenditures
# min         3589.0        -3.07          -0.05        1.201000e+06
# max       226181.0        32.36           1.00        5.827667e+09

# %% [markdown]
# We can notice negative ACT/SAT scores are not valid and percent_lunch should be between 0 and 100. There are large outliers in median household income (226k$) and expedinture variation from 1.2M$ to 5.8B$.
#
# Next we will remove invalid values.

# %% [markdown]
# #### Invalid values removal

# %% [markdown]
# Here we will remove invalid ACT/SAT scores and percent_lunch values from the dataset.

# %%
act_count = (df['average_act'] < 1).sum()
lunch_count = (df['percent_lunch'] < 0).sum()

print(f"Found invalid ACT scores (< 1):{act_count}")
print(f"Found invalid lunch percentages (< 0):{lunch_count}")

df.loc[df['average_act'] < 1, 'average_act'] = np.nan
df.loc[df['percent_lunch'] < 0, 'percent_lunch'] = np.nan
df.select_dtypes(include=['number']).agg(['min','max']).round(2)
# Out:
# Found invalid ACT scores (< 1):3
# Found invalid lunch percentages (< 0):20
#                id  rate_unemployment  percent_college  percent_married  \
# min  100001600143               0.00             0.09              0.0
# max  560583000335               0.59             1.00              1.0
#
#      median_income  average_act  percent_lunch  total_expenditures
# min         3589.0        12.36            0.0        1.201000e+06
# max       226181.0        32.36            1.0        5.827667e+09

# %% [markdown]
# #### Evaluate school characteristics and filter dataset to relevant schools

# %% [markdown]
# We will evaluate school characteristics and filter the dataset to relevant schools.

# %% [markdown]
# ##### Examine school characteristics data

# %%
for col in ['school_level', 'school_type', 'charter']:
    print(f"\n{col}:")
    print(df[col].value_counts())
# Out:
# school_level:
# school_level
# High            7230
# Other            631
# Not reported      35
# Elementary         2
# Name: count, dtype: int64
#
# school_type:
# school_type
# Regular School                 7885
# Alternative School               10
# Special Education School          2
# Career and Technical School       1
# Name: count, dtype: int64
#
# charter:
# charter
# No                7329
# Yes                352
# Not applicable     217
# Name: count, dtype: int64

# %% [markdown]
# ACT/SAT scores are administered at the high school level, making other school levels (elementary, middle) irrelevant for this
# analysis. However, we retain all school types (regular, alternative, special education) and ownership structures (charter, non-charter).

# %% [markdown]
# ##### Reduce dataset to high schools only

# %%
print("\nBefore filtering")
print(df['school_level'].value_counts())

df = df.loc[df['school_level'] == 'High']

print("\nAfter filtering")
print(df['school_level'].value_counts())
# Out:
# Before filtering
# school_level
# High            7230
# Other            631
# Not reported      35
# Elementary         2
# Name: count, dtype: int64
#
# After filtering
# school_level
# High    7230
# Name: count, dtype: int64

# %% [markdown]
# #### Evaluate Missing Values

# %% [markdown]
# Evaluate dataset completeness by calculating the percentage of missing values for each column. This will help us understand the extent of missing data and help us decide on imputation strategies.

# %%
percent_missing = df.isna().mean().round(4) * 100
# Format as percentage string with 2 decimal places
percent_missing = percent_missing.map("{:.2f}%".format)

percent_missing.to_frame(name='Percent Missing Values')
# Out:
#                    Percent Missing Values
# id                                  0.00%
# rate_unemployment                   0.17%
# percent_college                     0.15%
# percent_married                     0.28%
# median_income                       0.22%
# average_act                         0.04%
# percent_lunch                       0.28%
# year                                0.00%
# state                               0.00%
# zip_code                            0.00%
# school_type                         0.00%
# school_level                        0.00%
# charter                             0.00%
# total_expenditures                  4.15%

# %% [markdown]
# Missing socioeconomic data was minimal (all core variables <0.3% missing), additional variable is missing around 4.15%. ACT/SAT score is missing for 0.04% schools which is minimal and those records can be dropped from  the analysis.

# %% [markdown]
# ##### Remove records that has missing ACT/SAT scores

# %%
df = df.dropna(subset=['average_act'])
df.isna().sum().to_frame(name='Number of Missing Values')
# Out:
#                     Number of Missing Values
# id                                         0
# rate_unemployment                         12
# percent_college                           11
# percent_married                           20
# median_income                             16
# average_act                                0
# percent_lunch                             20
# year                                       0
# state                                      0
# zip_code                                   0
# school_type                                0
# school_level                               0
# charter                                    0
# total_expenditures                       300

# %% [markdown]
# ##### Impute Missing Socioeconomic Data

# %% [markdown]
# As we identified earlier, there is minimal missing core socioeconomic data. We will impute missing values using iterative imputer which is using regression models to estimate missing values based on other variables in the dataset.
# Steps performed:
# -  Define the predictor variables to be `rate_unemployment`, `percent_college`, `percent_married`, `median_income`, `percent_lunch`, `state`, `charter`, and additional predictor`total_expenditures`.
# - Then using iterative imputer from sklearn to perform regression-based Imputation.

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

predictor_variables = [
    'rate_unemployment',
    'percent_college',
    'percent_married',
    'median_income',
    'percent_lunch',
    'state',
    'charter',
    'total_expenditures'
]

imputer = IterativeImputer()

# Select only numerical predictor variables for imputation
numerical_predictors = df[predictor_variables].select_dtypes(include='number').columns.to_list()

imputer.fit(df.loc[:, numerical_predictors])

df.loc[:, numerical_predictors] = imputer.transform(df.loc[:, numerical_predictors])

#df['any_imputed'] = df[[f'{col}_imputed' for col in numerical_predictors]].any(axis=1).astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7227 entries, 0 to 7985
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  7227 non-null   int64
#  1   rate_unemployment   7227 non-null   float64
#  2   percent_college     7227 non-null   float64
#  3   percent_married     7227 non-null   float64
#  4   median_income       7227 non-null   float64
#  5   average_act         7227 non-null   float64
#  6   percent_lunch       7227 non-null   float64
#  7   year                7227 non-null   object
#  8   state               7227 non-null   object
#  9   zip_code            7227 non-null   object
#  10  school_type         7227 non-null   object
#  11  school_level        7227 non-null   object
#  12  charter             7227 non-null   object
#  13  total_expenditures  7227 non-null   float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 846.9+ KB

# %% [markdown]
# Imputation using iterative imputer allows us to make use of the existing relationships between variables to estimate missing values more accurately than simpler methods like mean or median imputation.

# %% [markdown]
# #### Evaluate Data Coverage

# %% [markdown]
# As we identified missing values in reported schools. We also need to evaluate how much data coverage we have across US. We will first evaluate schools reported by state to understand geographic coverage.

# %% [markdown]
# ##### Schools by state evaluation

# %%
df['state'].value_counts()
# Out:
# state
# TX    913
# OH    654
# IL    564
# PA    543
# MI    498
# NC    407
# FL    404
# GA    367
# WI    351
# NJ    338
# MO    337
# IN    321
# NY    295
# TN    265
# WA    263
# MA    253
# KY    198
# LA    194
# WY     38
# DE     24
# Name: count, dtype: int64

# %%
df['state'].nunique()
# Out:
# 20

# %% [markdown]
# We can notice that there is a lot of states missing from the dataset which indicates  incomplete geographic coverage.  Let's visualize the map of states with reported schools in the dataset for better understanding of geographic coverage.

# %% [markdown]
# ##### States Coverage On The Map
# For better visualization, we present the states coverage on a map to identify trends and gaps in the data coverage across the US.

# %%
import plotly.offline as po
import plotly.graph_objs as pg

layout = dict(
    geo={"scope": "usa"}, coloraxis_colorbar=dict(title="Number of Schools")
)

data = dict(
    type="choropleth",
    locations=df["state"].value_counts().index,
    locationmode="USA-states",
    z=df["state"].value_counts().values,
    coloraxis="coloraxis",
)

x = pg.Figure(data=[data], layout=layout)

po.iplot(x)

# %% [markdown]
# Based on above evaluation there is significant number of states unreported with schools in the dataset. We can see that coverage is concentrated in midwest and some southern states, with large gaps in the west and some in the east. This indicates that our dataset may not be fully representative of the entire US, and we should be cautious when generalizing findings from this data.

# %% [markdown]
# #### Data Preparation Summary
#
# We merged ACT/SAT performance data with school characteristics, resulting in 7,227 high schools across 20 US states. We reduced records to high schools only, cleaned invalid values, removed records with missing ACT/SAT scores, and imputed minimal missing socioeconomic data using iterative regression.
#
# It is important to note that geographic coverage is incomplete with significant gaps in Western and Eastern states, making the dataset not relevant for nationwide generalizations..

# %% [markdown]
# ## Save the cleaned and merged dataframe to a CSV file

# %%
### Save the cleaned and merged dataframe to a CSV file
df.to_csv('../data/education_data_cleaned.csv', index=False)
